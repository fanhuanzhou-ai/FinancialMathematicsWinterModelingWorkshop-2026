# %%
# ============================================================
# Imports
# ============================================================

import pandas as pd
import numpy as np
import statsmodels.api as sm

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings("ignore")

# ============================================================
# Utility Functions
# ============================================================

def log_return(series):
    return np.log(series).diff()

def safe_diff(series):
    return series.diff()

# ============================================================
# Data Loading Helper
# ============================================================

def load_excel_series(path, sheet, column=None):
    df = pd.read_excel(path, sheet_name=sheet)
    df["Date"] = pd.to_datetime(df["Date"])
    df = df.set_index("Date").sort_index()
    return df[column] if column else df

# ============================================================
# Load Data
# ============================================================

portfolio = load_excel_series("Workshop Data.xlsx", "Portfolio")

vix = load_excel_series("MOVE Vix prices.xlsx", "VIX", "PX_LAST")

ig_index = load_excel_series(
    "Indexes and Spreads Data 01.09.xlsx", "IG Index"
)
hy_index = load_excel_series(
    "Indexes and Spreads Data 01.09.xlsx", "HY Index"
)

# ============================================================
# SPY Total Return Construction
# ============================================================

if "TotalReturnsSPY" not in portfolio.columns:
    portfolio["SPYCumDiv"] = portfolio["SPY Dividends"][::-1].cumsum()[::-1]
    portfolio["TotalReturnsSPY"] = (
        portfolio["SPY Position"] + portfolio["SPYCumDiv"]
    )

# ============================================================
# Resampling + Model Function
# ============================================================

def run_spy_factor_model(freq_label, freq):

    print(f"\n================ {freq_label.upper()} MODEL =================")

    # ---------------- SPY Return ----------------
    spy_ret = (
        portfolio["TotalReturnsSPY"]
        .resample(freq)
        .last()
        .pct_change()
        .rename("SPY_Return")
    )

    # ---------------- VIX (Volatility Shock) ----------------
    vix_rs = vix.resample(freq).last()
    vix_change = safe_diff(vix_rs).rename("VIX_Change")

    # ---------------- Credit Factors ----------------
    ig_oas = ig_index["OAS_SOVEREIGN_CURVE"].resample(freq).last()
    hy_oas = hy_index["OAS_SOVEREIGN_CURVE"].resample(freq).last()

    ig_credit = safe_diff(ig_oas).rename("IG_Credit")
    credit_stress = (safe_diff(hy_oas) - safe_diff(ig_oas)).rename("Credit_Stress")

    # ---------------- Assemble Factor Matrix ----------------
    factors = pd.concat(
        [vix_change, ig_credit, credit_stress],
        axis=1
    )

    # ---------------- SAFE DATE ALIGNMENT ----------------
    data = pd.concat(
        [spy_ret, factors],
        axis=1,
        join="inner"
    ).dropna()

    y = data["SPY_Return"]
    X = data.drop(columns=["SPY_Return"])

    # ========================================================
    # OLS Regression
    # ========================================================

    X_ols = sm.add_constant(X)
    ols_model = sm.OLS(y, X_ols).fit()

    print("\nOLS Summary:")
    print(ols_model.summary())

    # ========================================================
    # PCA on Factors
    # ========================================================

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    pca = PCA(n_components=min(3, X.shape[1]))
    pcs = pca.fit_transform(X_scaled)

    pca_df = pd.DataFrame(
        pcs,
        index=X.index,
        columns=[f"PC{i+1}" for i in range(pcs.shape[1])]
    )

    explained_var = pd.Series(
        pca.explained_variance_ratio_,
        index=pca_df.columns,
        name="Explained Variance"
    )

    print("\nPCA Explained Variance:")
    print(explained_var)

    # ========================================================
    # PCA Regression
    # ========================================================

    X_pca = sm.add_constant(pca_df)
    pca_model = sm.OLS(y, X_pca).fit()

    print("\nPCA Regression Summary:")
    print(pca_model.summary())

    return {
        "OLS_Model": ols_model,
        "PCA_Model": pca_model,
        "PCA_Loadings": pd.DataFrame(
            pca.components_.T,
            index=X.columns,
            columns=pca_df.columns
        ),
        "Explained_Variance": explained_var
    }

# ============================================================
# Run Models at All Frequencies
# ============================================================

daily_results   = run_spy_factor_model("Daily", "D")
weekly_results  = run_spy_factor_model("Weekly", "W")
monthly_results = run_spy_factor_model("Monthly", "M")
# Out:
# ================ DAILY MODEL =================
#
# OLS Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.5105
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):              0.675
# Time:                        16:53:36   Log-Likelihood:                 3114.8
# No. Observations:                 994   AIC:                            -6222.
# Df Residuals:                     990   BIC:                            -6202.
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0004      0.000      1.279      0.201      -0.000       0.001
# VIX_Change        0.0001      0.000      0.479      0.632      -0.000       0.001
# IG_Credit        -0.0222      0.024     -0.927      0.354      -0.069       0.025
# Credit_Stress    -0.0011      0.006     -0.183      0.855      -0.013       0.011
# ==============================================================================
# Omnibus:                      239.401   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5045.433
# Skew:                           0.547   Prob(JB):                         0.00
# Kurtosis:                      13.983   Cond. No.                         131.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# PCA Explained Variance:
# PC1    0.668479
# PC2    0.207632
# PC3    0.123889
# Name: Explained Variance, dtype: float64
#
# PCA Regression Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.5105
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):              0.675
# Time:                        16:53:36   Log-Likelihood:                 3114.8
# No. Observations:                 994   AIC:                            -6222.
# Df Residuals:                     990   BIC:                            -6202.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      1.308      0.191      -0.000       0.001
# PC1           -0.0002      0.000     -0.847      0.397      -0.001       0.000
# PC2            0.0003      0.000      0.798      0.425      -0.000       0.001
# PC3            0.0002      0.001      0.420      0.674      -0.001       0.001
# ==============================================================================
# Omnibus:                      239.401   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5045.433
# Skew:                           0.547   Prob(JB):                         0.00
# Kurtosis:                      13.983   Cond. No.                         2.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================ WEEKLY MODEL =================
#
# OLS Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.2768
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):              0.842
# Time:                        16:53:36   Log-Likelihood:                 623.83
# No. Observations:                 259   AIC:                            -1240.
# Df Residuals:                     255   BIC:                            -1225.
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0022      0.001      1.615      0.107      -0.000       0.005
# VIX_Change        0.0002      0.001      0.403      0.688      -0.001       0.001
# IG_Credit         0.0115      0.037      0.309      0.758      -0.062       0.085
# Credit_Stress     0.0014      0.011      0.127      0.899      -0.021       0.024
# ==============================================================================
# Omnibus:                       13.226   Durbin-Watson:                   2.167
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               28.159
# Skew:                          -0.178   Prob(JB):                     7.68e-07
# Kurtosis:                       4.576   Cond. No.                         92.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# PCA Explained Variance:
# PC1    0.707188
# PC2    0.179031
# PC3    0.113781
# Name: Explained Variance, dtype: float64
#
# PCA Regression Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.2768
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):              0.842
# Time:                        16:53:36   Log-Likelihood:                 623.83
# No. Observations:                 259   AIC:                            -1240.
# Df Residuals:                     255   BIC:                            -1225.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0022      0.001      1.602      0.110      -0.001       0.005
# PC1            0.0008      0.001      0.897      0.370      -0.001       0.003
# PC2            0.0002      0.002      0.093      0.926      -0.003       0.004
# PC3           -0.0003      0.002     -0.130      0.897      -0.005       0.004
# ==============================================================================
# Omnibus:                       13.226   Durbin-Watson:                   2.167
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               28.159
# Skew:                          -0.178   Prob(JB):                     7.68e-07
# Kurtosis:                       4.576   Cond. No.                         2.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================ MONTHLY MODEL =================
#
# OLS Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.392
# Model:                            OLS   Adj. R-squared:                  0.359
# Method:                 Least Squares   F-statistic:                     11.84
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):           4.31e-06
# Time:                        16:53:36   Log-Likelihood:                 116.58
# No. Observations:                  59   AIC:                            -225.2
# Df Residuals:                      55   BIC:                            -216.9
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0079      0.005      1.736      0.088      -0.001       0.017
# VIX_Change       -0.0028      0.001     -2.290      0.026      -0.005      -0.000
# IG_Credit        -0.0590      0.066     -0.891      0.377      -0.192       0.074
# Credit_Stress    -0.0359      0.018     -1.975      0.053      -0.072       0.001
# ==============================================================================
# Omnibus:                        9.186   Durbin-Watson:                   2.402
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):               18.122
# Skew:                           0.294   Prob(JB):                     0.000116
# Kurtosis:                       5.651   Cond. No.                         70.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# PCA Explained Variance:
# PC1    0.732806
# PC2    0.152705
# PC3    0.114489
# Name: Explained Variance, dtype: float64
#
# PCA Regression Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.392
# Model:                            OLS   Adj. R-squared:                  0.359
# Method:                 Least Squares   F-statistic:                     11.84
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):           4.31e-06
# Time:                        16:53:36   Log-Likelihood:                 116.58
# No. Observations:                  59   AIC:                            -225.2
# Df Residuals:                      55   BIC:                            -216.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0094      0.005      2.074      0.043       0.000       0.018
# PC1           -0.0180      0.003     -5.901      0.000      -0.024      -0.012
# PC2           -0.0035      0.007     -0.517      0.607      -0.017       0.010
# PC3            0.0051      0.008      0.667      0.508      -0.010       0.021
# ==============================================================================
# Omnibus:                        9.186   Durbin-Watson:                   2.402
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):               18.122
# Skew:                           0.294   Prob(JB):                     0.000116
# Kurtosis:                       5.651   Cond. No.                         2.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# ============================================================
# Imports
# ============================================================

import pandas as pd
import numpy as np
import statsmodels.api as sm

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings("ignore")

# ============================================================
# Utility Functions
# ============================================================

def log_return(series):
    return np.log(series).diff()

def safe_diff(series):
    return series.diff()

# ============================================================
# Data Loading Helper
# ============================================================

def load_excel_series(path, sheet, column=None):
    df = pd.read_excel(path, sheet_name=sheet)
    df["Date"] = pd.to_datetime(df["Date"])
    df = df.set_index("Date").sort_index()
    return df[column] if column else df

# ============================================================
# Load Data
# ============================================================

portfolio = load_excel_series("Workshop Data.xlsx", "Portfolio")

spy_vol = load_excel_series(
    "Workshop Data.xlsx", "SPY", "Volume"
)

vix = load_excel_series(
    "MOVE Vix prices.xlsx", "VIX", "PX_LAST"
)

ig_index = load_excel_series(
    "Indexes and Spreads Data 01.09.xlsx", "IG Index"
)

hy_index = load_excel_series(
    "Indexes and Spreads Data 01.09.xlsx", "HY Index"
)

# ============================================================
# SPY Total Return Construction
# ============================================================

if "TotalReturnsSPY" not in portfolio.columns:
    portfolio["SPYCumDiv"] = portfolio["SPY Dividends"][::-1].cumsum()[::-1]
    portfolio["TotalReturnsSPY"] = (
        portfolio["SPY Position"] + portfolio["SPYCumDiv"]
    )

# ============================================================
# Resampling + Model Function
# ============================================================

def run_spy_factor_model(freq_label, freq):

    print(f"\n================ {freq_label.upper()} MODEL =================")

    # ---------------- SPY Return ----------------
    spy_ret = (
        portfolio["TotalReturnsSPY"]
        .resample(freq)
        .last()
        .pct_change()
        .rename("SPY_Return")
    )

    # ---------------- VIX (Volatility) ----------------
    vix_rs = vix.resample(freq).last()
    vix_change = safe_diff(vix_rs).rename("VIX_Change")

    # ---------------- Credit Factors ----------------
    ig_oas = ig_index["OAS_SOVEREIGN_CURVE"].resample(freq).last()
    hy_oas = hy_index["OAS_SOVEREIGN_CURVE"].resample(freq).last()

    ig_credit = safe_diff(ig_oas).rename("IG_Credit")
    credit_stress = (safe_diff(hy_oas) - safe_diff(ig_oas)).rename("Credit_Stress")

    # ---------------- Liquidity Factor (NEW) ----------------
    spy_vol_rs = spy_vol.resample(freq).last()
    liquidity = log_return(spy_vol_rs).rename("Liquidity")

    # ---------------- Assemble Factor Matrix ----------------
    factors = pd.concat(
        [vix_change, ig_credit, credit_stress, liquidity],
        axis=1
    )

    # ---------------- SAFE DATE ALIGNMENT ----------------
    data = pd.concat(
        [spy_ret, factors],
        axis=1,
        join="inner"
    ).dropna()

    y = data["SPY_Return"]
    X = data.drop(columns=["SPY_Return"])

    # ========================================================
    # OLS Regression
    # ========================================================

    X_ols = sm.add_constant(X)
    ols_model = sm.OLS(y, X_ols).fit()

    print("\nOLS Summary:")
    print(ols_model.summary())

    # ========================================================
    # PCA on Factors
    # ========================================================

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    pca = PCA(n_components=min(3, X.shape[1]))
    pcs = pca.fit_transform(X_scaled)

    pca_df = pd.DataFrame(
        pcs,
        index=X.index,
        columns=[f"PC{i+1}" for i in range(pcs.shape[1])]
    )

    explained_var = pd.Series(
        pca.explained_variance_ratio_,
        index=pca_df.columns,
        name="Explained Variance"
    )

    print("\nPCA Explained Variance:")
    print(explained_var)

    # ========================================================
    # PCA Regression
    # ========================================================

    X_pca = sm.add_constant(pca_df)
    pca_model = sm.OLS(y, X_pca).fit()

    print("\nPCA Regression Summary:")
    print(pca_model.summary())

    return {
        "OLS_Model": ols_model,
        "PCA_Model": pca_model,
        "PCA_Loadings": pd.DataFrame(
            pca.components_.T,
            index=X.columns,
            columns=pca_df.columns
        ),
        "Explained_Variance": explained_var
    }

# ============================================================
# Run Models at All Frequencies
# ============================================================

daily_results   = run_spy_factor_model("Daily", "D")
weekly_results  = run_spy_factor_model("Weekly", "W")
monthly_results = run_spy_factor_model("Monthly", "M")
# Out:
# ================ DAILY MODEL =================
#
# OLS Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.3627
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):              0.835
# Time:                        17:09:30   Log-Likelihood:                 3032.7
# No. Observations:                 971   AIC:                            -6055.
# Df Residuals:                     966   BIC:                            -6031.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0004      0.000      1.113      0.266      -0.000       0.001
# VIX_Change       9.7e-05      0.000      0.428      0.669      -0.000       0.001
# IG_Credit        -0.0223      0.024     -0.921      0.357      -0.070       0.025
# Credit_Stress    -0.0009      0.006     -0.145      0.885      -0.013       0.011
# Liquidity        -0.0001      0.001     -0.078      0.937      -0.003       0.003
# ==============================================================================
# Omnibus:                      233.108   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4731.095
# Skew:                           0.554   Prob(JB):                         0.00
# Kurtosis:                      13.757   Cond. No.                         131.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# PCA Explained Variance:
# PC1    0.529160
# PC2    0.246546
# PC3    0.131279
# Name: Explained Variance, dtype: float64
#
# PCA Regression Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.4147
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):              0.742
# Time:                        17:09:30   Log-Likelihood:                 3032.6
# No. Observations:                 971   AIC:                            -6057.
# Df Residuals:                     967   BIC:                            -6038.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      1.151      0.250      -0.000       0.001
# PC1           -0.0002      0.000     -0.777      0.437      -0.001       0.000
# PC2            0.0002      0.000      0.558      0.577      -0.000       0.001
# PC3            0.0003      0.000      0.573      0.567      -0.001       0.001
# ==============================================================================
# Omnibus:                      233.529   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4726.878
# Skew:                           0.558   Prob(JB):                         0.00
# Kurtosis:                      13.751   Cond. No.                         2.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================ WEEKLY MODEL =================
#
# OLS Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.2915
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):              0.883
# Time:                        17:09:30   Log-Likelihood:                 624.00
# No. Observations:                 259   AIC:                            -1238.
# Df Residuals:                     254   BIC:                            -1220.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0022      0.001      1.616      0.107      -0.000       0.005
# VIX_Change        0.0004      0.001      0.638      0.524      -0.001       0.002
# IG_Credit         0.0092      0.037      0.247      0.805      -0.064       0.083
# Credit_Stress     0.0018      0.011      0.156      0.876      -0.020       0.024
# Liquidity        -0.0023      0.004     -0.581      0.562      -0.010       0.006
# ==============================================================================
# Omnibus:                       13.672   Durbin-Watson:                   2.161
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               29.649
# Skew:                          -0.184   Prob(JB):                     3.64e-07
# Kurtosis:                       4.616   Cond. No.                         93.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# PCA Explained Variance:
# PC1    0.599953
# PC2    0.225651
# PC3    0.089910
# Name: Explained Variance, dtype: float64
#
# PCA Regression Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.3495
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):              0.790
# Time:                        17:09:30   Log-Likelihood:                 623.94
# No. Observations:                 259   AIC:                            -1240.
# Df Residuals:                     255   BIC:                            -1226.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0022      0.001      1.603      0.110      -0.000       0.005
# PC1            0.0007      0.001      0.754      0.452      -0.001       0.002
# PC2           -0.0007      0.001     -0.519      0.604      -0.004       0.002
# PC3            0.0010      0.002      0.460      0.646      -0.003       0.006
# ==============================================================================
# Omnibus:                       13.550   Durbin-Watson:                   2.162
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               29.104
# Skew:                          -0.185   Prob(JB):                     4.79e-07
# Kurtosis:                       4.600   Cond. No.                         2.58
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================ MONTHLY MODEL =================
#
# OLS Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.394
# Model:                            OLS   Adj. R-squared:                  0.349
# Method:                 Least Squares   F-statistic:                     8.779
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):           1.56e-05
# Time:                        17:09:30   Log-Likelihood:                 116.66
# No. Observations:                  59   AIC:                            -223.3
# Df Residuals:                      54   BIC:                            -212.9
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0079      0.005      1.729      0.090      -0.001       0.017
# VIX_Change       -0.0025      0.001     -1.724      0.091      -0.005       0.000
# IG_Credit        -0.0641      0.068     -0.941      0.351      -0.201       0.072
# Credit_Stress    -0.0351      0.018     -1.900      0.063      -0.072       0.002
# Liquidity        -0.0058      0.016     -0.372      0.711      -0.037       0.025
# ==============================================================================
# Omnibus:                        9.040   Durbin-Watson:                   2.432
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               18.110
# Skew:                           0.266   Prob(JB):                     0.000117
# Kurtosis:                       5.662   Cond. No.                         72.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# PCA Explained Variance:
# PC1    0.624853
# PC2    0.213258
# PC3    0.093669
# Name: Explained Variance, dtype: float64
#
# PCA Regression Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.389
# Model:                            OLS   Adj. R-squared:                  0.355
# Method:                 Least Squares   F-statistic:                     11.66
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):           5.08e-06
# Time:                        17:09:30   Log-Likelihood:                 116.40
# No. Observations:                  59   AIC:                            -224.8
# Df Residuals:                      55   BIC:                            -216.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0094      0.005      2.068      0.043       0.000       0.018
# PC1           -0.0169      0.003     -5.879      0.000      -0.023      -0.011
# PC2            0.0031      0.005      0.633      0.530      -0.007       0.013
# PC3           -0.0009      0.007     -0.124      0.902      -0.016       0.014
# ==============================================================================
# Omnibus:                        9.223   Durbin-Watson:                   2.499
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):               19.108
# Skew:                           0.258   Prob(JB):                     7.09e-05
# Kurtosis:                       5.740   Cond. No.                         2.58
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
