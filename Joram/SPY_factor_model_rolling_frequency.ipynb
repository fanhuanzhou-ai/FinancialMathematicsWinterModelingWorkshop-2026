# %%
# ============================================================
# Imports
# ============================================================

import pandas as pd
import numpy as np
import statsmodels.api as sm

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings("ignore")

# ============================================================
# Utility Functions
# ============================================================

def log_return(series):
    return np.log(series).diff()

def safe_diff(series):
    return series.diff()

# ============================================================
# Data Loading Helper
# ============================================================

def load_excel_series(path, sheet, column=None):
    df = pd.read_excel(path, sheet_name=sheet)
    df["Date"] = pd.to_datetime(df["Date"])
    df = df.set_index("Date").sort_index()
    return df[column] if column else df

# ============================================================
# Load Data
# ============================================================

portfolio = load_excel_series("Workshop Data.xlsx", "Portfolio")

spy_vol = load_excel_series(
    "Workshop Data.xlsx", "SPY", "Volume"
)

vix = load_excel_series(
    "MOVE Vix prices.xlsx", "VIX", "PX_LAST"
)

ig_index = load_excel_series(
    "Indexes and Spreads Data 01.09.xlsx", "IG Index"
)

hy_index = load_excel_series(
    "Indexes and Spreads Data 01.09.xlsx", "HY Index"
)

# ============================================================
# SPY Total Return Construction
# ============================================================

if "TotalReturnsSPY" not in portfolio.columns:
    portfolio["SPYCumDiv"] = portfolio["SPY Dividends"][::-1].cumsum()[::-1]
    portfolio["TotalReturnsSPY"] = (
        portfolio["SPY Position"] + portfolio["SPYCumDiv"]
    )

# ============================================================
# Resampling + Model Function
# ============================================================

def run_spy_factor_model(freq_label, freq):

    print(f"\n================ {freq_label.upper()} MODEL =================")

    # ---------------- SPY Return ----------------
    spy_ret = (
        portfolio["TotalReturnsSPY"]
        .resample(freq)
        .last()
        .pct_change()
        .rename("SPY_Return")
    )

    # ---------------- VIX (Volatility) ----------------
    vix_rs = vix.resample(freq).last()
    vix_change = safe_diff(vix_rs).rename("VIX_Change")

    # ---------------- Credit Factors ----------------
    ig_oas = ig_index["OAS_SOVEREIGN_CURVE"].resample(freq).last()
    hy_oas = hy_index["OAS_SOVEREIGN_CURVE"].resample(freq).last()

    ig_credit = safe_diff(ig_oas).rename("IG_Credit")
    credit_stress = (safe_diff(hy_oas) - safe_diff(ig_oas)).rename("Credit_Stress")

    # ---------------- Liquidity Factor (NEW) ----------------
    spy_vol_rs = spy_vol.resample(freq).last()
    liquidity = log_return(spy_vol_rs).rename("Liquidity")

    # ---------------- Assemble Factor Matrix ----------------
    factors = pd.concat(
        [vix_change, ig_credit, credit_stress, liquidity],
        axis=1
    )

    # ---------------- SAFE DATE ALIGNMENT ----------------
    data = pd.concat(
        [spy_ret, factors],
        axis=1,
        join="inner"
    ).dropna()

    y = data["SPY_Return"]
    X = data.drop(columns=["SPY_Return"])

    # ========================================================
    # OLS Regression
    # ========================================================

    X_ols = sm.add_constant(X)
    ols_model = sm.OLS(y, X_ols).fit()

    print("\nOLS Summary:")
    print(ols_model.summary())

    # ========================================================
    # PCA on Factors
    # ========================================================

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    pca = PCA(n_components=min(3, X.shape[1]))
    pcs = pca.fit_transform(X_scaled)

    pca_df = pd.DataFrame(
        pcs,
        index=X.index,
        columns=[f"PC{i+1}" for i in range(pcs.shape[1])]
    )

    explained_var = pd.Series(
        pca.explained_variance_ratio_,
        index=pca_df.columns,
        name="Explained Variance"
    )

    print("\nPCA Explained Variance:")
    print(explained_var)

    # ========================================================
    # PCA Regression
    # ========================================================

    X_pca = sm.add_constant(pca_df)
    pca_model = sm.OLS(y, X_pca).fit()

    print("\nPCA Regression Summary:")
    print(pca_model.summary())

    return {
        "OLS_Model": ols_model,
        "PCA_Model": pca_model,
        "PCA_Loadings": pd.DataFrame(
            pca.components_.T,
            index=X.columns,
            columns=pca_df.columns
        ),
        "Explained_Variance": explained_var
    }

# ============================================================
# Run Models at All Frequencies
# ============================================================

daily_results   = run_spy_factor_model("Daily", "D")
weekly_results  = run_spy_factor_model("Weekly", "W")
monthly_results = run_spy_factor_model("Monthly", "M")
# Out:
# ================ DAILY MODEL =================
#
# OLS Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.669
# Method:                 Least Squares   F-statistic:                     490.3
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):          9.04e-231
# Time:                        20:41:36   Log-Likelihood:                 3562.1
# No. Observations:                 971   AIC:                            -7114.
# Df Residuals:                     966   BIC:                            -7090.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0001      0.000     -0.719      0.473      -0.001       0.000
# VIX_Change       -0.0039      0.000    -29.940      0.000      -0.004      -0.004
# IG_Credit        -0.0781      0.014     -5.560      0.000      -0.106      -0.051
# Credit_Stress    -0.0243      0.004     -6.696      0.000      -0.031      -0.017
# Liquidity         0.0015      0.001      1.835      0.067      -0.000       0.003
# ==============================================================================
# Omnibus:                      115.024   Durbin-Watson:                   2.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1020.217
# Skew:                           0.048   Prob(JB):                    2.90e-222
# Kurtosis:                       8.021   Cond. No.                         131.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# PCA Explained Variance:
# PC1    0.529160
# PC2    0.246546
# PC3    0.131279
# Name: Explained Variance, dtype: float64
#
# PCA Regression Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.669
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                     652.8
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):          7.15e-232
# Time:                        20:41:36   Log-Likelihood:                 3561.3
# No. Observations:                 971   AIC:                            -7115.
# Df Residuals:                     967   BIC:                            -7095.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      2.044      0.041    1.63e-05       0.001
# PC1           -0.0055      0.000    -40.057      0.000      -0.006      -0.005
# PC2           -0.0003      0.000     -1.492      0.136      -0.001    9.42e-05
# PC3           -0.0051      0.000    -18.754      0.000      -0.006      -0.005
# ==============================================================================
# Omnibus:                      114.746   Durbin-Watson:                   2.224
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1015.290
# Skew:                           0.044   Prob(JB):                    3.41e-221
# Kurtosis:                       8.009   Cond. No.                         2.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================ WEEKLY MODEL =================
#
# OLS Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.677
# Method:                 Least Squares   F-statistic:                     136.1
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):           5.93e-62
# Time:                        20:41:36   Log-Likelihood:                 773.71
# No. Observations:                 259   AIC:                            -1537.
# Df Residuals:                     254   BIC:                            -1520.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0020      0.001      2.562      0.011       0.000       0.003
# VIX_Change       -0.0035      0.000    -10.612      0.000      -0.004      -0.003
# IG_Credit        -0.0571      0.021     -2.720      0.007      -0.098      -0.016
# Credit_Stress    -0.0358      0.006     -5.669      0.000      -0.048      -0.023
# Liquidity        -0.0011      0.002     -0.493      0.622      -0.006       0.003
# ==============================================================================
# Omnibus:                       20.880   Durbin-Watson:                   2.214
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.306
# Skew:                           0.153   Prob(JB):                     5.41e-16
# Kurtosis:                       5.534   Cond. No.                         93.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# PCA Explained Variance:
# PC1    0.599953
# PC2    0.225651
# PC3    0.089910
# Name: Explained Variance, dtype: float64
#
# PCA Regression Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.677
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     178.2
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):           2.77e-62
# Time:                        20:41:36   Log-Likelihood:                 771.75
# No. Observations:                 259   AIC:                            -1536.
# Df Residuals:                     255   BIC:                            -1521.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0022      0.001      2.883      0.004       0.001       0.004
# PC1           -0.0112      0.000    -22.492      0.000      -0.012      -0.010
# PC2            0.0003      0.001      0.386      0.699      -0.001       0.002
# PC3           -0.0069      0.001     -5.338      0.000      -0.009      -0.004
# ==============================================================================
# Omnibus:                       21.191   Durbin-Watson:                   2.241
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               61.685
# Skew:                           0.259   Prob(JB):                     4.03e-14
# Kurtosis:                       5.334   Cond. No.                         2.58
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================ MONTHLY MODEL =================
#
# OLS Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.727
# Model:                            OLS   Adj. R-squared:                  0.707
# Method:                 Least Squares   F-statistic:                     36.01
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):           1.19e-14
# Time:                        20:41:36   Log-Likelihood:                 141.79
# No. Observations:                  59   AIC:                            -273.6
# Df Residuals:                      54   BIC:                            -263.2
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0079      0.003      2.640      0.011       0.002       0.014
# VIX_Change       -0.0037      0.001     -3.863      0.000      -0.006      -0.002
# IG_Credit        -0.0659      0.044     -1.481      0.144      -0.155       0.023
# Credit_Stress    -0.0524      0.012     -4.350      0.000      -0.077      -0.028
# Liquidity         0.0022      0.010      0.216      0.830      -0.018       0.023
# ==============================================================================
# Omnibus:                        0.387   Durbin-Watson:                   2.104
# Prob(Omnibus):                  0.824   Jarque-Bera (JB):                0.556
# Skew:                          -0.114   Prob(JB):                        0.757
# Kurtosis:                       2.583   Cond. No.                         72.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# PCA Explained Variance:
# PC1    0.624853
# PC2    0.213258
# PC3    0.093669
# Name: Explained Variance, dtype: float64
#
# PCA Regression Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SPY_Return   R-squared:                       0.704
# Model:                            OLS   Adj. R-squared:                  0.688
# Method:                 Least Squares   F-statistic:                     43.64
# Date:                Fri, 16 Jan 2026   Prob (F-statistic):           1.44e-14
# Time:                        20:41:36   Log-Likelihood:                 139.39
# No. Observations:                  59   AIC:                            -270.8
# Df Residuals:                      55   BIC:                            -262.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0099      0.003      3.214      0.002       0.004       0.016
# PC1           -0.0219      0.002    -11.276      0.000      -0.026      -0.018
# PC2            0.0064      0.003      1.910      0.061      -0.000       0.013
# PC3           -0.0018      0.005     -0.356      0.723      -0.012       0.008
# ==============================================================================
# Omnibus:                        1.349   Durbin-Watson:                   2.187
# Prob(Omnibus):                  0.509   Jarque-Bera (JB):                0.712
# Skew:                          -0.221   Prob(JB):                        0.700
# Kurtosis:                       3.306   Cond. No.                         2.58
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
